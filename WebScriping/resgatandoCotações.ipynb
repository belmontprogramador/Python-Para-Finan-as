# %% [markdown]
# # Aula extra - Como analisar os dados de rentabilidade?
#
# ### Desafio:
#
# * Construir um código que faça um ranking dos melhores fundos em três períodos de rentabilidade diferentes. Iremos selecionar os 10 melhores posicionados no quesito rentabilidade no curto e no longo prazo.
#
# * Essa aula será mais curta.
#
# ### Passo a passo:
#
#    **Passo 1** - Puxar as tabelas igual na aula 2.
#
#    **Passo 2** - Escolher quais períodos de rentabilidade iremos analisar.
#
#    **Passo 3** - Retirar os dados faltantes. Fundos que não possuem os períodos necessários, ficarão de fora.
#
#    **Passo 4** - Transformar as rentabilidades em números decimais, ao invés de string.
#
#    **Passo 5** - Juntar as tabelas, igual na aula 2.
#
#    **Passo 6** - Filtrar os ETFs alavancados.
#
#    **Passo 7** - Fazer os rankings de rentabilidade por período e soma-los.
#
#    **Passo 8** - Ordenar do menor ranking pro maior, encontrando os "melhores" ETFs.

# %% [markdown]
# # Passo 1: Puxar as tabelas igual na aula 2.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

driver.get('https://www.etf.com/etfanalytics/etf-finder')

time.sleep(5)

botao_100 = driver.find_element("xpath",
                               '/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span')

driver.execute_script("arguments[0].click();", botao_100)

numero_paginas = driver.find_element("xpath", '//*[@id="totalPages"]')

numero_paginas = numero_paginas.text.replace("of ", "")

numero_paginas = int(numero_paginas)

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

html_tabela = elemento.get_attribute('outerHTML')

lista_tabela_por_pagina = []

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

for pagina in range(1, numero_paginas + 1):
    
    html_tabela = elemento.get_attribute('outerHTML')
    
    tabela = pd.read_html(str(html_tabela))[0]
    
    lista_tabela_por_pagina.append(tabela)
    
    botao_avancar_pagina = driver.find_element("xpath", '//*[@id="nextPage"]')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
    
tabela_cadastro_etfs = pd.concat(lista_tabela_por_pagina)


formulario_de_voltar_pagina = driver.find_element("xpath", '//*[@id="goToPage"]')

formulario_de_voltar_pagina.clear()
formulario_de_voltar_pagina.send_keys("1")
formulario_de_voltar_pagina.send_keys(u'\ue007')

botao_mudar_pra_performance = driver.find_element("xpath", '/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span')

driver.execute_script("arguments[0].click();", botao_mudar_pra_performance)

# a partir daqui é tudo igual

lista_tabela_por_pagina = []

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

for pagina in range(1, numero_paginas + 1):
    
    html_tabela = elemento.get_attribute('outerHTML')
    
    tabela = pd.read_html(str(html_tabela))[0]
    
    lista_tabela_por_pagina.append(tabela)
    
    botao_avancar_pagina = driver.find_element("xpath", '//*[@id="nextPage"]')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
    
tabela_rentabilidade_etfs = pd.concat(lista_tabela_por_pagina)

driver.quit()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.79M/6.79M [00:01<00:00, 4.95MB/s]

# %%
tabela_cadastro_etfs = tabela_cadastro_etfs.set_index('Ticker')
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.set_index("Ticker")

# %% [markdown]
# # Passo 2: Escolher quais períodos de rentabilidade iremos analisar.
#
# No nosso caso, iremos pegar as janelas de 1, 3 e 5 anos.

# %%
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs[['1 Year', '3 Years', '5 Years']]

tabela_rentabilidade_etfs
# Out:
#          1 Year 3 Years 5 Years
# Ticker
# SPY      -9.01%  19.91%  11.05%
# IVV      -9.02%  19.97%  11.06%
# VOO      -9.02%  19.98%  11.07%
# VTI     -10.30%  19.93%  10.25%
# QQQ     -12.94%  21.03%  15.65%
# ...         ...     ...     ...
# CVLC         --      --      --
# CVMC         --      --      --
# CVIE         --      --      --
# CDEI         --      --      --
# USCA         --      --      --
#
# [3125 rows x 3 columns]

# %% [markdown]
# # Passo 3: Retirar os dados faltantes. Fundos que não possuem os períodos necessários, ficarão de fora.

# %%
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.replace("--", pd.NA)

tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.dropna()

# %% [markdown]
# # Passo 4: Transformar as rentabilidades em números decimais

# %%
for coluna in tabela_rentabilidade_etfs.columns:
    
    tabela_rentabilidade_etfs[coluna] = tabela_rentabilidade_etfs[coluna].str.rstrip("%").astype(float)/100

# %% [markdown]
# # Passo 5: Juntar as tabelas, igual na aula 2.

# %%
base_final = tabela_cadastro_etfs.join(tabela_rentabilidade_etfs, how = "inner")

base_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VOO                               Vanguard S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# LTL             ProShares Ultra Communication Services
# RSXJ                       VanEck Russia Small-Cap ETF
# FLRU                          Franklin FTSE Russia ETF
#
#                                               Segment  \
# Ticker
# SPY                          Equity: U.S. - Large Cap
# IVV                          Equity: U.S. - Large Cap
# VOO                          Equity: U.S. - Large Cap
# VTI                       Equity: U.S. - Total Market
# QQQ                          Equity: U.S. - Large Cap
# ...                                               ...
# LD                Commodities: Industrial Metals Lead
# ERUS                    Equity: Russia - Total Market
# LTL     Leveraged Equity: U.S. Communication Services
# RSXJ                       Equity: Russia - Small Cap
# FLRU                    Equity: Russia - Total Market
#
#                               Issuer Expense Ratio       AUM  1 Year  3 Years  \
# Ticker
# SPY     State Street Global Advisors         0.09%  $374.42B -0.0901   0.1991
# IVV                        Blackrock         0.03%  $306.66B -0.0902   0.1997
# VOO                         Vanguard         0.03%  $287.12B -0.0902   0.1998
# VTI                         Vanguard         0.03%  $282.79B -0.1030   0.1993
# QQQ                          Invesco         0.20%  $172.68B -0.1294   0.2103
# ...                              ...           ...       ...     ...      ...
# LD             Barclays Capital Inc.         0.70%    $1.24M -0.0942   0.1026
# ERUS                       Blackrock         0.08%  $961.13K  0.0000  -0.3319
# LTL                        ProShares         0.95%  $692.87K -0.2630   0.1248
# RSXJ                          VanEck         0.67%  $387.25K -0.0050  -0.2017
# FLRU              Franklin Templeton         0.19%    $8.00K  0.0000  -0.1995
#
#         5 Years
# Ticker
# SPY      0.1105
# IVV      0.1106
# VOO      0.1107
# VTI      0.1025
# QQQ      0.1565
# ...         ...
# LD      -0.0212
# ERUS    -0.2274
# LTL      0.0136
# RSXJ    -0.2035
# FLRU    -0.1449
#
# [1557 rows x 8 columns]

# %% [markdown]
# # Passo 6: Filtrar os ETFs alavancados.

# %%
base_final = base_final[~base_final['Segment'].str.contains("Leveraged")]

base_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VOO                               Vanguard S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# SDP                     ProShares UltraShort Utilities
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
# FLRU                          Franklin FTSE Russia ETF
#
#                                     Segment                        Issuer  \
# Ticker
# SPY                Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                Equity: U.S. - Large Cap                     Blackrock
# VOO                Equity: U.S. - Large Cap                      Vanguard
# VTI             Equity: U.S. - Total Market                      Vanguard
# QQQ                Equity: U.S. - Large Cap                       Invesco
# ...                                     ...                           ...
# SDP          Inverse Equity: U.S. Utilities                     ProShares
# LD      Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS          Equity: Russia - Total Market                     Blackrock
# RSXJ             Equity: Russia - Small Cap                        VanEck
# FLRU          Equity: Russia - Total Market            Franklin Templeton
#
#        Expense Ratio       AUM  1 Year  3 Years  5 Years
# Ticker
# SPY            0.09%  $374.42B -0.0901   0.1991   0.1105
# IVV            0.03%  $306.66B -0.0902   0.1997   0.1106
# VOO            0.03%  $287.12B -0.0902   0.1998   0.1107
# VTI            0.03%  $282.79B -0.1030   0.1993   0.1025
# QQQ            0.20%  $172.68B -0.1294   0.2103   0.1565
# ...              ...       ...     ...      ...      ...
# SDP            0.95%    $1.96M  0.0526  -0.2945  -0.2642
# LD             0.70%    $1.24M -0.0942   0.1026  -0.0212
# ERUS           0.08%  $961.13K  0.0000  -0.3319  -0.2274
# RSXJ           0.67%  $387.25K -0.0050  -0.2017  -0.2035
# FLRU           0.19%    $8.00K  0.0000  -0.1995  -0.1449
#
# [1479 rows x 8 columns]

# %% [markdown]
# # Passo 7: Fazer os rankings de rentabilidade por período e soma-los.

# %%
base_final['rank_1_anos'] = base_final['1 Year'].rank(ascending = False)
base_final['rank_3_anos'] = base_final['3 Years'].rank(ascending = False)
base_final['rank_5_anos'] = base_final['5 Years'].rank(ascending = False)
base_final['rank_final'] = (base_final['rank_1_anos'] + 
                                  base_final['rank_3_anos'] + 
                                  base_final['rank_5_anos'])

base_final
# Out:
# C:\Users\Felipe Belmont\AppData\Local\Temp\ipykernel_28564\3578762214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_1_anos'] = base_final['1 Year'].rank(ascending = False)
# C:\Users\Felipe Belmont\AppData\Local\Temp\ipykernel_28564\3578762214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_3_anos'] = base_final['3 Years'].rank(ascending = False)
# C:\Users\Felipe Belmont\AppData\Local\Temp\ipykernel_28564\3578762214.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_5_anos'] = base_final['5 Years'].rank(ascending = False)
# C:\Users\Felipe Belmont\AppData\Local\Temp\ipykernel_28564\3578762214.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_final'] = (base_final['rank_1_anos'] +
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VOO                               Vanguard S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# SDP                     ProShares UltraShort Utilities
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
# FLRU                          Franklin FTSE Russia ETF
#
#                                     Segment                        Issuer  \
# Ticker
# SPY                Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                Equity: U.S. - Large Cap                     Blackrock
# VOO                Equity: U.S. - Large Cap                      Vanguard
# VTI             Equity: U.S. - Total Market                      Vanguard
# QQQ                Equity: U.S. - Large Cap                       Invesco
# ...                                     ...                           ...
# SDP          Inverse Equity: U.S. Utilities                     ProShares
# LD      Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS          Equity: Russia - Total Market                     Blackrock
# RSXJ             Equity: Russia - Small Cap                        VanEck
# FLRU          Equity: Russia - Total Market            Franklin Templeton
#
#        Expense Ratio       AUM  1 Year  3 Years  5 Years  rank_1_anos  \
# Ticker
# SPY            0.09%  $374.42B -0.0901   0.1991   0.1105        920.5
# IVV            0.03%  $306.66B -0.0902   0.1997   0.1106        923.5
# VOO            0.03%  $287.12B -0.0902   0.1998   0.1107        923.5
# VTI            0.03%  $282.79B -0.1030   0.1993   0.1025       1022.0
# QQQ            0.20%  $172.68B -0.1294   0.2103   0.1565       1170.5
# ...              ...       ...     ...      ...      ...          ...
# SDP            0.95%    $1.96M  0.0526  -0.2945  -0.2642        100.0
# LD             0.70%    $1.24M -0.0942   0.1026  -0.0212        950.0
# ERUS           0.08%  $961.13K  0.0000  -0.3319  -0.2274        256.5
# RSXJ           0.67%  $387.25K -0.0050  -0.2017  -0.2035        283.0
# FLRU           0.19%    $8.00K  0.0000  -0.1995  -0.1449        256.5
#
#         rank_3_anos  rank_5_anos  rank_final
# Ticker
# SPY           434.0        101.0      1455.5
# IVV           423.5         99.5      1446.5
# VOO           421.5         97.5      1442.5
# VTI           431.5        151.5      1605.0
# QQQ           340.0         14.0      1524.5
# ...             ...          ...         ...
# SDP          1444.0       1456.0      3000.0
# LD            977.0       1299.0      3226.0
# ERUS         1449.0       1446.0      3151.5
# RSXJ         1433.0       1440.0      3156.0
# FLRU         1432.0       1432.0      3120.5
#
# [1479 rows x 12 columns]

# %% [markdown]
# # Passo 8: Gran finale - Ordenar do menor ranking pro maior, encontrando os "melhores" ETFs.

# %%
base_final = base_final.sort_values(by = "rank_final")

base_final.head(20)
# Out:
#                                                      Name  \
# Ticker
# UGA                        United States Gasoline Fund LP
# ITB                    iShares U.S. Home Construction ETF
# AIRR    First Trust RBA American Industrial Renaissanc...
# XLE                        Energy Select Sector SPDR Fund
# SGG     iPath Series B Bloomberg Sugar Subindex Total ...
# GRID    First Trust NASDAQ Clean Edge Smart Grid Infra...
# IEO     iShares U.S. Oil & Gas Exploration & Productio...
# FENY                       Fidelity MSCI Energy Index ETF
# VDE                                   Vanguard Energy ETF
# XHB                             SPDR S&P Homebuilders ETF
# IYE                               iShares U.S. Energy ETF
# FTXN                     First Trust Nasdaq Oil & Gas ETF
# IYK                     iShares U.S. Consumer Staples ETF
# RYE               Invesco S&P 500 Equal Weight Energy ETF
# CHIE                       Global X MSCI China Energy ETF
# PSCC            Invesco S&P SmallCap Consumer Staples ETF
# XSD                            SPDR S&P Semiconductor ETF
# EDEN                             iShares MSCI Denmark ETF
# IXC                             iShares Global Energy ETF
# NANR        SPDR S&P North American Natural Resources ETF
#
#                                                 Segment  \
# Ticker
# UGA                        Commodities: Energy Gasoline
# ITB                                Equity: U.S. Housing
# AIRR                           Equity: U.S. Industrials
# XLE                                 Equity: U.S. Energy
# SGG                      Commodities: Agriculture Sugar
# GRID                      Equity: Global Infrastructure
# IEO     Equity: U.S. Oil & Gas Exploration & Production
# FENY                                Equity: U.S. Energy
# VDE                                 Equity: U.S. Energy
# XHB                                Equity: U.S. Housing
# IYE                                 Equity: U.S. Energy
# FTXN                                Equity: U.S. Energy
# IYK                       Equity: U.S. Consumer Staples
# RYE                                 Equity: U.S. Energy
# CHIE                               Equity: China Energy
# PSCC                      Equity: U.S. Consumer Staples
# XSD                         Equity: U.S. Semiconductors
# EDEN                     Equity: Denmark - Total Market
# IXC                               Equity: Global Energy
# NANR            Equity: North America Natural Resources
#
#                                           Issuer Expense Ratio       AUM  \
# Ticker
# UGA                                     Marygold         0.93%   $74.99M
# ITB                                    Blackrock         0.39%    $1.64B
# AIRR                                 First Trust         0.70%  $316.07M
# XLE                 State Street Global Advisors         0.10%   $40.36B
# SGG                        Barclays Capital Inc.         0.45%   $41.42M
# GRID                                 First Trust         0.58%  $719.10M
# IEO                                    Blackrock         0.39%  $764.20M
# FENY                                    Fidelity         0.08%    $1.59B
# VDE                                     Vanguard         0.10%    $8.03B
# XHB                 State Street Global Advisors         0.35%  $952.93M
# IYE                                    Blackrock         0.39%    $1.64B
# FTXN                                 First Trust         0.60%  $314.33M
# IYK                                    Blackrock         0.39%    $1.75B
# RYE                                      Invesco         0.40%  $528.33M
# CHIE    Mirae Asset Global Investments Co., Ltd.         0.66%   $10.79M
# PSCC                                     Invesco         0.29%   $65.67M
# XSD                 State Street Global Advisors         0.35%    $1.55B
# EDEN                                   Blackrock         0.53%  $237.24M
# IXC                                    Blackrock         0.40%    $1.89B
# NANR                State Street Global Advisors         0.35%  $597.71M
#
#         1 Year  3 Years  5 Years  rank_1_anos  rank_3_anos  rank_5_anos  \
# Ticker
# UGA     0.0931   0.7312   0.1455         59.0          2.0         20.0
# ITB     0.1548   0.3995   0.1200         20.0         37.0         50.0
# AIRR    0.0936   0.3608   0.1244         58.0         59.0         42.0
# XLE     0.1489   0.4855   0.1016         22.0         20.0        156.5
# SGG     0.2770   0.3192   0.1078          7.0         82.0        124.0
# GRID    0.0181   0.3512   0.1558        156.0         65.0         16.0
# IEO     0.0667   0.6024   0.1005         78.0          6.0        164.5
# FENY    0.1340   0.5000   0.0913         26.0         19.0        235.0
# VDE     0.1304   0.5050   0.0916         29.0         18.0        233.0
# XHB     0.0349   0.3667   0.1082        118.0         56.0        119.5
# IYE     0.1250   0.4743   0.0852         35.0         21.0        294.5
# FTXN    0.0414   0.5392   0.0902        111.0         11.0        247.0
# IYK     0.0136   0.2545   0.1310        173.0        171.0         35.0
# RYE     0.0675   0.5536   0.0845         77.0         10.0        300.0
# CHIE    0.1175   0.2700   0.0925         42.5        146.0        221.0
# PSCC    0.0770   0.2395   0.1075         69.0        236.0        126.0
# XSD    -0.0280   0.3620   0.2413        403.0         57.0          2.0
# EDEN    0.0541   0.2280   0.1109         97.0        274.5         96.0
# IXC     0.1154   0.3721   0.0764         44.0         51.0        388.0
# NANR   -0.0309   0.3866   0.1339        425.5         46.0         33.0
#
#         rank_final
# Ticker
# UGA           81.0
# ITB          107.0
# AIRR         159.0
# XLE          198.5
# SGG          213.0
# GRID         237.0
# IEO          248.5
# FENY         280.0
# VDE          280.0
# XHB          293.5
# IYE          350.5
# FTXN         369.0
# IYK          379.0
# RYE          387.0
# CHIE         409.5
# PSCC         431.0
# XSD          462.0
# EDEN         467.5
# IXC          483.0
# NANR         504.5
